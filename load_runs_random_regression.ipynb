# %%
import os
import pandas as pd
import numpy as np

def list_files(directory):
    files = []
    for entry in os.listdir(directory):
        if os.path.isfile(os.path.join(directory, entry)):
            files.append(entry)
    return files

# %%
path1 = "results_regression_random_gnn"

# %%
files = list_files(path1)
print(files)
# Out:
# ['model_gnn_conv', 'model_gnn_conv_1', 'model_gnn_conv_10', 'model_gnn_conv_100', 'model_gnn_conv_101', 'model_gnn_conv_102', 'model_gnn_conv_103', 'model_gnn_conv_104', 'model_gnn_conv_105', 'model_gnn_conv_106', 'model_gnn_conv_107', 'model_gnn_conv_11', 'model_gnn_conv_12', 'model_gnn_conv_13', 'model_gnn_conv_14', 'model_gnn_conv_15', 'model_gnn_conv_16', 'model_gnn_conv_17', 'model_gnn_conv_18', 'model_gnn_conv_19', 'model_gnn_conv_2', 'model_gnn_conv_20', 'model_gnn_conv_21', 'model_gnn_conv_22', 'model_gnn_conv_23', 'model_gnn_conv_24', 'model_gnn_conv_25', 'model_gnn_conv_26', 'model_gnn_conv_27', 'model_gnn_conv_28', 'model_gnn_conv_29', 'model_gnn_conv_3', 'model_gnn_conv_30', 'model_gnn_conv_31', 'model_gnn_conv_32', 'model_gnn_conv_33', 'model_gnn_conv_34', 'model_gnn_conv_35', 'model_gnn_conv_36', 'model_gnn_conv_37', 'model_gnn_conv_38', 'model_gnn_conv_39', 'model_gnn_conv_4', 'model_gnn_conv_40', 'model_gnn_conv_41', 'model_gnn_conv_42', 'model_gnn_conv_43', 'model_gnn_conv_44', 'model_gnn_conv_45', 'model_gnn_conv_46', 'model_gnn_conv_47', 'model_gnn_conv_48', 'model_gnn_conv_49', 'model_gnn_conv_5', 'model_gnn_conv_50', 'model_gnn_conv_51', 'model_gnn_conv_52', 'model_gnn_conv_53', 'model_gnn_conv_54', 'model_gnn_conv_55', 'model_gnn_conv_56', 'model_gnn_conv_57', 'model_gnn_conv_58', 'model_gnn_conv_59', 'model_gnn_conv_6', 'model_gnn_conv_60', 'model_gnn_conv_61', 'model_gnn_conv_62', 'model_gnn_conv_63', 'model_gnn_conv_64', 'model_gnn_conv_65', 'model_gnn_conv_66', 'model_gnn_conv_67', 'model_gnn_conv_68', 'model_gnn_conv_69', 'model_gnn_conv_7', 'model_gnn_conv_70', 'model_gnn_conv_71', 'model_gnn_conv_72', 'model_gnn_conv_73', 'model_gnn_conv_74', 'model_gnn_conv_75', 'model_gnn_conv_76', 'model_gnn_conv_77', 'model_gnn_conv_78', 'model_gnn_conv_79', 'model_gnn_conv_8', 'model_gnn_conv_80', 'model_gnn_conv_81', 'model_gnn_conv_82', 'model_gnn_conv_83', 'model_gnn_conv_84', 'model_gnn_conv_85', 'model_gnn_conv_86', 'model_gnn_conv_87', 'model_gnn_conv_88', 'model_gnn_conv_89', 'model_gnn_conv_9', 'model_gnn_conv_90', 'model_gnn_conv_91', 'model_gnn_conv_92', 'model_gnn_conv_93', 'model_gnn_conv_94', 'model_gnn_conv_95', 'model_gnn_conv_96', 'model_gnn_conv_97', 'model_gnn_conv_98', 'model_gnn_conv_99']

# %%
file1_load = []
import dill as pickle

for file in files:
    file_path = os.path.join(path1, file)
    with open(file_path, 'rb') as filel:
        loaded_data = pickle.load(filel)
    file1_load.append(loaded_data)

# %%
file1_load
# Out:
# [{'pred_df':     y_real    y_pred
#   0    -3.85 -4.088128
#   1     0.79 -0.508802
#   2    -1.82 -2.222143
#   3    -1.73 -2.840542
#   4    -3.40 -3.117310
#   ..     ...       ...
#   43   -5.03 -4.832994
#   44   -7.85 -6.906616
#   45   -7.42 -7.309327
#   46   -5.24 -4.641108
#   47   -3.10 -2.841666
#
#   [112 rows x 2 columns],
#   'el_time': 151.7859513759613,
#   'mean_mse': 1.1591473,
#   'mean_l1': 0.7628732,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -5.400 -3.844608
#   1   -4.370 -2.951296
#   2   -0.440 -1.991730
#   3   -5.030 -3.728957
#   4   -5.507 -4.752553
#   ..     ...       ...
#   43  -1.614 -2.442656
#   44  -2.780 -2.923781
#   45  -3.140 -4.494146
#   46  -3.630 -3.005170
#   47  -4.630 -4.080516
#
#   [112 rows x 2 columns],
#   'el_time': 160.8419439792633,
#   'mean_mse': 1.8799496,
#   'mean_l1': 1.0856783,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -1.228 -1.077164
#   1   -6.250 -5.945365
#   2   -0.720 -1.627365
#   3   -4.310 -4.618680
#   4   -5.240 -5.469907
#   ..     ...       ...
#   43  -0.400 -0.709204
#   44  -0.220  0.676199
#   45  -1.060 -1.618092
#   46  -3.140 -2.436934
#   47   0.522  0.209987
#
#   [112 rows x 2 columns],
#   'el_time': 123.17934942245483,
#   'mean_mse': 0.74970293,
#   'mean_l1': 0.661114,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.030 -0.911019
#   1   -4.380 -5.098431
#   2   -2.280 -2.252560
#   3   -0.220  0.718318
#   4   -1.220 -1.442903
#   ..     ...       ...
#   43  -3.510 -3.504679
#   44  -9.160 -8.144958
#   45  -2.730 -4.038616
#   46  -3.300 -4.075398
#   47  -4.173 -4.665781
#
#   [112 rows x 2 columns],
#   'el_time': 124.59206700325012,
#   'mean_mse': 0.76435494,
#   'mean_l1': 0.69570285,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 2,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1): GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.083 -2.215265
#   1   -1.520 -2.155728
#   2   -4.370 -3.351645
#   3    0.510 -0.278864
#   4   -2.460 -1.919450
#   ..     ...       ...
#   43  -5.400 -3.400564
#   44  -1.110 -1.362856
#   45  -3.928 -3.056267
#   46  -3.510 -3.365825
#   47   0.540 -0.131426
#
#   [112 rows x 2 columns],
#   'el_time': 78.14021825790405,
#   'mean_mse': 0.92706966,
#   'mean_l1': 0.6594926,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 2,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1): GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -4.110 -4.447846
#   1   -4.173 -4.305691
#   2   -1.614 -1.270557
#   3   -5.840 -5.051085
#   4   -1.290 -1.357222
#   ..     ...       ...
#   43  -0.390 -0.117739
#   44   0.610 -0.847861
#   45  -3.630 -3.937622
#   46  -3.680 -3.449519
#   47   0.790 -0.175884
#
#   [112 rows x 2 columns],
#   'el_time': 116.925696849823,
#   'mean_mse': 0.5076616,
#   'mean_l1': 0.5119028,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 3,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-2): 2 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.220 -3.679260
#   1   -0.040 -0.040269
#   2   -2.218 -2.395730
#   3   -5.240 -5.791505
#   4   -5.507 -5.400540
#   ..     ...       ...
#   43  -7.420 -7.576974
#   44   0.510 -1.141088
#   45  -0.807 -1.018812
#   46  -1.990 -2.827105
#   47  -3.400 -2.968220
#
#   [112 rows x 2 columns],
#   'el_time': 106.31875348091125,
#   'mean_mse': 0.6356126,
#   'mean_l1': 0.5953475,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 3,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-2): 2 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.360 -1.155734
#   1   -4.370 -3.340680
#   2   -1.110 -2.339493
#   3   -5.233 -5.081388
#   4   -0.040 -0.196919
#   ..     ...       ...
#   43   0.620 -0.493507
#   44  -0.600 -0.490414
#   45  -3.900 -4.303043
#   46  -2.420 -3.429466
#   47  -2.770 -3.129110
#
#   [112 rows x 2 columns],
#   'el_time': 82.40869951248169,
#   'mean_mse': 0.73011065,
#   'mean_l1': 0.60170674,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 3,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-2): 2 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.180 -0.398791
#   1   -1.640 -2.234784
#   2   -4.799 -3.166074
#   3   -4.280 -4.493299
#   4   -0.720 -0.782507
#   ..     ...       ...
#   43  -3.083 -2.367954
#   44  -0.600 -1.033116
#   45  -9.160 -9.483118
#   46  -3.630 -4.129411
#   47   0.620  0.250014
#
#   [112 rows x 2 columns],
#   'el_time': 74.59504389762878,
#   'mean_mse': 0.702078,
#   'mean_l1': 0.6197658,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 4,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-3): 3 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.400  0.154317
#   1   -4.470 -4.508743
#   2   -5.915 -5.382083
#   3   -2.460 -2.562383
#   4   -2.280 -1.172934
#   ..     ...       ...
#   43  -2.850 -3.752794
#   44  -0.180 -0.450429
#   45  -4.310 -4.726167
#   46  -4.173 -4.258391
#   47  -1.290 -1.580747
#
#   [112 rows x 2 columns],
#   'el_time': 75.79402565956116,
#   'mean_mse': 0.6255185,
#   'mean_l1': 0.6037512,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 4,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-3): 3 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -1.520 -2.312172
#   1   -3.796 -4.085800
#   2   -6.250 -6.337630
#   3   -3.010 -3.104350
#   4   -2.850 -3.104553
#   ..     ...       ...
#   43  -2.676 -2.724925
#   44  -0.360 -1.298875
#   45  -2.770 -2.875024
#   46  -1.340 -1.097076
#   47  -2.840 -3.932340
#
#   [112 rows x 2 columns],
#   'el_time': 96.40254664421082,
#   'mean_mse': 0.7828132,
#   'mean_l1': 0.639094,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 4,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-3): 3 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -1.300 -2.016211
#   1   -5.115 -6.098012
#   2   -0.040  0.068752
#   3    0.510 -1.056664
#   4   -4.345 -3.948596
#   ..     ...       ...
#   43  -0.600 -0.651408
#   44  -7.420 -7.949973
#   45  -2.380 -2.399456
#   46  -3.300 -3.995728
#   47  -1.060 -1.529374
#
#   [112 rows x 2 columns],
#   'el_time': 159.36079049110413,
#   'mean_mse': 0.74632263,
#   'mean_l1': 0.6330613,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.720 -1.182998
#   1   -1.947 -1.476823
#   2    0.580  0.504681
#   3   -2.000 -1.901874
#   4   -0.360  0.042405
#   ..     ...       ...
#   43  -0.220  0.087369
#   44  -1.820 -2.026385
#   45  -0.040 -0.077687
#   46  -2.850 -2.577217
#   47  -2.820 -3.459548
#
#   [112 rows x 2 columns],
#   'el_time': 157.72912096977234,
#   'mean_mse': 1.0048348,
#   'mean_l1': 0.7249667,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.850 -2.745618
#   1   -2.420 -4.014833
#   2   -1.228 -2.053726
#   3   -0.807 -2.009762
#   4   -2.210 -1.767445
#   ..     ...       ...
#   43  -1.640 -1.341188
#   44  -2.730 -3.010841
#   45  -7.420 -5.775803
#   46  -1.220 -2.093214
#   47  -1.820 -2.039908
#
#   [112 rows x 2 columns],
#   'el_time': 147.32967853546143,
#   'mean_mse': 1.9988186,
#   'mean_l1': 1.1119666,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.770 -3.595182
#   1   -3.300 -1.238107
#   2   -5.915 -4.932846
#   3   -0.600 -0.383884
#   4   -1.730 -2.933755
#   ..     ...       ...
#   43  -3.010 -3.462693
#   44  -3.850 -3.821747
#   45  -2.218 -2.358340
#   46  -1.228 -1.808393
#   47  -3.010 -1.966873
#
#   [112 rows x 2 columns],
#   'el_time': 151.70299196243286,
#   'mean_mse': 1.9558108,
#   'mean_l1': 0.9837289,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.620  0.392895
#   1   -2.218 -2.156689
#   2   -2.070 -3.890186
#   3   -5.400 -3.559944
#   4    0.580  0.145614
#   ..     ...       ...
#   43  -7.200 -5.822229
#   44   0.620 -0.314194
#   45  -1.947 -2.107952
#   46  -0.440 -0.857777
#   47  -2.840 -4.271188
#
#   [112 rows x 2 columns],
#   'el_time': 81.05938172340393,
#   'mean_mse': 1.0326114,
#   'mean_l1': 0.73967505,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.400  0.185386
#   1   -4.370 -2.967774
#   2   -4.920 -4.541844
#   3   -3.928 -3.987516
#   4   -3.680 -3.685001
#   ..     ...       ...
#   43  -3.510 -3.892449
#   44  -2.420 -4.353340
#   45  -9.160 -7.415719
#   46  -3.630 -3.404098
#   47  -2.380 -2.220322
#
#   [112 rows x 2 columns],
#   'el_time': 140.38668870925903,
#   'mean_mse': 1.2162175,
#   'mean_l1': 0.83674216,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.030 -2.012818
#   1   -1.990 -0.726593
#   2   -0.807 -1.164443
#   3   -3.450 -4.665707
#   4   -5.030 -3.815957
#   ..     ...       ...
#   43   0.430 -0.324950
#   44  -3.630 -3.845605
#   45  -7.200 -6.054593
#   46  -5.115 -5.113048
#   47  -6.291 -6.233944
#
#   [112 rows x 2 columns],
#   'el_time': 218.82394862174988,
#   'mean_mse': 1.3437426,
#   'mean_l1': 0.8972715,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -7.850 -7.497845
#   1   -2.280 -3.724117
#   2    0.009 -1.559383
#   3   -1.820 -1.515204
#   4   -2.840 -4.673898
#   ..     ...       ...
#   43  -0.807 -0.670982
#   44  -2.380 -2.792006
#   45  -3.460 -2.441193
#   46  -3.510 -3.542071
#   47  -1.458 -0.549684
#
#   [112 rows x 2 columns],
#   'el_time': 127.57513213157654,
#   'mean_mse': 0.84534943,
#   'mean_l1': 0.6814271,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 3,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-2): 2 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.510 -1.319647
#   1   -2.550 -3.777290
#   2   -3.010 -3.240339
#   3   -1.640 -2.022085
#   4   -5.240 -5.676415
#   ..     ...       ...
#   43  -2.730 -3.985684
#   44  -2.770 -2.966918
#   45  -3.928 -3.910335
#   46   1.100  0.061564
#   47  -0.400  0.069147
#
#   [112 rows x 2 columns],
#   'el_time': 151.038920879364,
#   'mean_mse': 0.8171768,
#   'mean_l1': 0.71391284,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 3,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-2): 2 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.360 -1.024873
#   1   -3.796 -3.283710
#   2   -2.420 -4.669973
#   3    0.510 -2.514366
#   4   -3.460 -3.154183
#   ..     ...       ...
#   43  -0.400 -0.252511
#   44  -4.920 -2.939767
#   45  -2.730 -5.027165
#   46  -7.200 -6.097939
#   47   1.100 -0.779719
#
#   [112 rows x 2 columns],
#   'el_time': 165.9344494342804,
#   'mean_mse': 1.8927695,
#   'mean_l1': 0.98083043,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.300 -3.257499
#   1   -2.210 -2.979588
#   2   -4.110 -3.872071
#   3   -4.630 -4.719312
#   4   -2.780 -2.421978
#   ..     ...       ...
#   43   1.100  0.808860
#   44  -4.799 -3.660675
#   45  -3.780 -3.924692
#   46  -1.060 -1.280236
#   47  -6.291 -6.226862
#
#   [112 rows x 2 columns],
#   'el_time': 156.79406547546387,
#   'mean_mse': 0.71599776,
#   'mean_l1': 0.5971156,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 3,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-2): 2 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.928 -2.676445
#   1   -2.070 -4.005856
#   2   -3.927 -1.632729
#   3   -3.450 -4.854082
#   4   -6.560 -4.566695
#   ..     ...       ...
#   43  -3.900 -2.968331
#   44   0.009 -1.131296
#   45  -3.630 -4.270348
#   46  -5.233 -5.477435
#   47  -0.390 -0.060865
#
#   [112 rows x 2 columns],
#   'el_time': 176.9735505580902,
#   'mean_mse': 0.72573704,
#   'mean_l1': 0.65391,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.620 -0.475729
#   1   -6.291 -5.693355
#   2   -1.990 -2.091956
#   3   -2.770 -3.115455
#   4   -2.080 -2.901898
#   ..     ...       ...
#   43  -1.614 -1.981261
#   44  -1.989 -2.145570
#   45  -1.870 -1.889675
#   46  -2.560 -2.512683
#   47  -5.840 -5.620006
#
#   [112 rows x 2 columns],
#   'el_time': 196.18530464172363,
#   'mean_mse': 0.81233406,
#   'mean_l1': 0.67956954,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.009 -1.153330
#   1    0.620 -0.062870
#   2   -3.400 -2.477034
#   3   -6.780 -6.023248
#   4   -4.920 -2.815094
#   ..     ...       ...
#   43  -3.630 -4.255962
#   44  -0.360 -0.383424
#   45  -2.210 -3.302266
#   46  -6.560 -5.143621
#   47  -2.210 -1.151153
#
#   [112 rows x 2 columns],
#   'el_time': 138.5555009841919,
#   'mean_mse': 0.8079255,
#   'mean_l1': 0.6411058,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.790 -0.268087
#   1   -9.160 -6.776969
#   2   -4.310 -4.194944
#   3   -4.799 -3.862994
#   4   -0.440 -0.770444
#   ..     ...       ...
#   43  -7.850 -6.977438
#   44  -1.458 -0.401907
#   45  -5.030 -5.137734
#   46  -0.360 -0.055022
#   47   0.610 -1.407372
#
#   [112 rows x 2 columns],
#   'el_time': 191.45237278938293,
#   'mean_mse': 1.1399915,
#   'mean_l1': 0.79010737,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.040 -0.822616
#   1   -0.180 -2.302103
#   2   -3.220 -2.999424
#   3    0.522 -1.660889
#   4   -0.807 -2.449822
#   ..     ...       ...
#   43  -1.520 -2.873223
#   44  -2.000 -2.422627
#   45  -1.947 -3.471000
#   46  -2.560 -1.779494
#   47  -9.160 -5.844063
#
#   [112 rows x 2 columns],
#   'el_time': 111.07231736183167,
#   'mean_mse': 2.3204849,
#   'mean_l1': 1.2291882,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.820 -4.114172
#   1   -2.080 -2.894463
#   2   -5.030 -4.953748
#   3   -6.250 -5.385530
#   4   -1.228 -2.187588
#   ..     ...       ...
#   43  -2.370 -1.583008
#   44  -3.300 -1.573368
#   45  -2.000 -2.489886
#   46  -3.460 -3.625294
#   47   0.620 -1.293900
#
#   [112 rows x 2 columns],
#   'el_time': 87.36834001541138,
#   'mean_mse': 2.1442456,
#   'mean_l1': 1.1350816,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 1,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.080 -2.432934
#   1   -0.600 -1.085489
#   2   -3.010 -2.983112
#   3    0.430  0.419871
#   4   -2.676 -2.469967
#   ..     ...       ...
#   43  -2.560 -2.547444
#   44   1.100  0.990086
#   45  -1.990 -2.389606
#   46  -4.173 -4.471123
#   47  -1.060 -1.414760
#
#   [112 rows x 2 columns],
#   'el_time': 116.3986234664917,
#   'mean_mse': 0.76657856,
#   'mean_l1': 0.6424719,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.100 -3.264274
#   1   -5.915 -4.244014
#   2   -3.460 -3.121331
#   3   -3.680 -3.579941
#   4   -4.110 -2.765697
#   ..     ...       ...
#   43  -1.458 -0.810640
#   44  -0.400  0.583451
#   45  -3.300 -2.996536
#   46  -1.520 -4.039996
#   47   0.522  1.390741
#
#   [112 rows x 2 columns],
#   'el_time': 105.48077464103699,
#   'mean_mse': 1.204106,
#   'mean_l1': 0.836429,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -7.850 -7.125465
#   1   -1.730 -2.319238
#   2   -2.000 -0.888237
#   3   -1.290 -0.884290
#   4   -5.233 -4.955820
#   ..     ...       ...
#   43   0.510 -1.197284
#   44  -1.220 -1.976558
#   45  -3.510 -3.376493
#   46  -1.820 -2.042154
#   47  -1.360 -1.633222
#
#   [112 rows x 2 columns],
#   'el_time': 84.33931016921997,
#   'mean_mse': 1.2140598,
#   'mean_l1': 0.7939133,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -9.160 -8.456048
#   1   -1.110 -1.888778
#   2    0.580  0.349795
#   3   -1.820 -1.585634
#   4   -3.680 -3.534486
#   ..     ...       ...
#   43  -1.290 -0.882661
#   44  -2.840 -4.630915
#   45  -5.840 -3.954772
#   46  -1.947 -1.401836
#   47  -1.870 -2.216856
#
#   [112 rows x 2 columns],
#   'el_time': 141.7468466758728,
#   'mean_mse': 0.73348475,
#   'mean_l1': 0.64064,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.796 -4.044131
#   1   -3.300 -3.056840
#   2   -3.010 -3.294254
#   3   -1.300 -1.410413
#   4    0.790 -0.248891
#   ..     ...       ...
#   43  -4.345 -3.939316
#   44   0.540 -1.369997
#   45  -0.180 -0.857715
#   46  -4.310 -4.289893
#   47  -0.360 -1.734927
#
#   [112 rows x 2 columns],
#   'el_time': 93.36275362968445,
#   'mean_mse': 1.071418,
#   'mean_l1': 0.7596569,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 3,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-2): 2 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.630 -3.685957
#   1   -2.460 -2.194906
#   2    0.009 -0.928252
#   3   -0.440 -2.168013
#   4   -4.630 -4.001461
#   ..     ...       ...
#   43  -1.520 -3.246481
#   44  -2.780 -1.997554
#   45  -1.990 -2.052452
#   46  -2.850 -3.399168
#   47  -6.250 -5.574102
#
#   [112 rows x 2 columns],
#   'el_time': 136.5989589691162,
#   'mean_mse': 1.0313673,
#   'mean_l1': 0.7860239,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 3,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-2): 2 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.600 -0.854746
#   1   -1.290 -0.944850
#   2   -3.400 -2.797416
#   3   -3.220 -3.456722
#   4   -1.458 -0.513933
#   ..     ...       ...
#   43  -0.440 -0.764382
#   44  -2.210 -2.873090
#   45  -2.080 -2.305475
#   46  -2.840 -3.871715
#   47  -1.300 -1.410163
#
#   [112 rows x 2 columns],
#   'el_time': 196.40371561050415,
#   'mean_mse': 0.66664815,
#   'mean_l1': 0.58739066,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 3,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-2): 2 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.360 -0.983660
#   1   -2.780 -2.296290
#   2   -0.807 -0.916350
#   3   -1.947 -2.181438
#   4   -3.630 -4.193626
#   ..     ...       ...
#   43  -1.228 -1.306638
#   44  -3.780 -3.960192
#   45  -4.380 -4.020222
#   46  -2.000 -1.187770
#   47  -1.614 -1.590071
#
#   [112 rows x 2 columns],
#   'el_time': 178.81715559959412,
#   'mean_mse': 0.671711,
#   'mean_l1': 0.62767565,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.928 -3.700058
#   1   -3.400 -2.751003
#   2   -0.180 -1.152370
#   3   -2.630 -4.122807
#   4   -0.030 -0.447109
#   ..     ...       ...
#   43  -3.100 -3.035896
#   44  -1.614 -1.818637
#   45  -2.730 -3.516607
#   46  -2.000 -0.527923
#   47  -1.360 -0.897632
#
#   [112 rows x 2 columns],
#   'el_time': 93.57751226425171,
#   'mean_mse': 0.84281766,
#   'mean_l1': 0.70365644,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    1.100  0.169348
#   1   -4.345 -3.373047
#   2   -2.420 -2.842410
#   3    0.790 -0.374172
#   4   -5.030 -4.313114
#   ..     ...       ...
#   43  -1.370 -1.688650
#   44  -1.520 -2.526425
#   45  -4.380 -4.795740
#   46   0.580  0.004036
#   47  -0.807 -0.752889
#
#   [112 rows x 2 columns],
#   'el_time': 146.11004447937012,
#   'mean_mse': 0.7032635,
#   'mean_l1': 0.612638,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -7.850 -6.979078
#   1   -3.100 -3.147360
#   2   -3.900 -2.993490
#   3   -7.200 -6.187130
#   4   -1.110 -2.181274
#   ..     ...       ...
#   43  -3.510 -3.933307
#   44   1.100 -0.028937
#   45  -5.030 -4.641920
#   46  -6.250 -5.612102
#   47  -5.233 -5.680902
#
#   [112 rows x 2 columns],
#   'el_time': 109.2954568862915,
#   'mean_mse': 1.3337921,
#   'mean_l1': 0.854193,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 1,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.220  0.302043
#   1   -1.228 -1.900043
#   2   -8.400 -3.750556
#   3   -0.400  0.284624
#   4   -3.400 -2.754139
#   ..     ...       ...
#   43  -9.160 -6.796739
#   44   0.430 -0.402196
#   45  -0.720 -2.614837
#   46  -1.060 -0.325496
#   47  -1.300 -1.148600
#
#   [112 rows x 2 columns],
#   'el_time': 139.73509454727173,
#   'mean_mse': 1.4756545,
#   'mean_l1': 0.9288472,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 1,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.009 -1.352458
#   1   -1.730 -2.555065
#   2   -4.345 -4.424802
#   3   -6.291 -6.365044
#   4   -3.850 -3.499068
#   ..     ...       ...
#   43   0.610 -1.226689
#   44  -3.010 -2.094952
#   45  -4.173 -4.480427
#   46  -2.420 -4.444103
#   47  -3.083 -2.308181
#
#   [112 rows x 2 columns],
#   'el_time': 120.07688021659851,
#   'mean_mse': 1.794586,
#   'mean_l1': 0.9656499,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 1,
#   'linear_sizes': [],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.370 -2.312401
#   1   -5.233 -6.051240
#   2    1.100  0.671234
#   3   -2.070 -2.560076
#   4   -1.300 -1.412604
#   ..     ...       ...
#   43  -4.470 -4.198883
#   44  -3.083 -2.598126
#   45  -9.160 -8.303329
#   46  -4.310 -3.859706
#   47  -0.220  0.033933
#
#   [112 rows x 2 columns],
#   'el_time': 109.93311667442322,
#   'mean_mse': 0.6328345,
#   'mean_l1': 0.60181195,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 2,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1): GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -1.640 -0.887397
#   1   -1.947 -1.763112
#   2   -2.560 -2.172811
#   3    0.540 -1.796589
#   4   -3.140 -3.071917
#   ..     ...       ...
#   43  -1.989 -2.289719
#   44  -4.920 -4.534197
#   45  -5.115 -4.289325
#   46  -5.915 -4.157455
#   47  -0.180 -1.721177
#
#   [112 rows x 2 columns],
#   'el_time': 93.94179224967957,
#   'mean_mse': 1.1227099,
#   'mean_l1': 0.80785394,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 2,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1): GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -4.310 -4.321295
#   1   -0.040  0.291553
#   2   -0.220  0.400481
#   3   -1.220 -2.114659
#   4   -5.240 -5.802509
#   ..     ...       ...
#   43  -4.630 -4.255224
#   44  -0.807 -0.859104
#   45  -7.850 -7.921973
#   46  -2.380 -2.484972
#   47  -7.200 -5.836302
#
#   [112 rows x 2 columns],
#   'el_time': 86.96033024787903,
#   'mean_mse': 0.99896276,
#   'mean_l1': 0.76635766,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 2,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1): GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.550 -3.348884
#   1   -2.780 -2.252186
#   2   -3.400 -3.195094
#   3   -0.030 -0.086325
#   4   -0.807 -0.553683
#   ..     ...       ...
#   43  -6.250 -5.997612
#   44  -4.280 -4.713982
#   45  -1.290 -0.766569
#   46  -1.360 -1.393410
#   47  -1.520 -2.192149
#
#   [112 rows x 2 columns],
#   'el_time': 115.7463448047638,
#   'mean_mse': 0.9643017,
#   'mean_l1': 0.65221024,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 2,
#   'linear_sizes': [],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1): GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -5.840 -5.151689
#   1   -1.060 -1.038387
#   2   -4.110 -4.684741
#   3   -1.220 -1.829932
#   4   -1.110 -2.193781
#   ..     ...       ...
#   43  -2.420 -3.494752
#   44  -4.920 -3.725137
#   45  -1.228 -1.258619
#   46  -4.470 -4.445584
#   47   0.540  0.672508
#
#   [112 rows x 2 columns],
#   'el_time': 146.94670271873474,
#   'mean_mse': 0.6625694,
#   'mean_l1': 0.586409,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 3,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1-2): 2 x GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.820 -4.410795
#   1   -1.989 -2.340558
#   2   -3.927 -1.230260
#   3   -7.200 -6.227337
#   4   -3.510 -3.499696
#   ..     ...       ...
#   43   0.430 -0.699901
#   44  -0.180 -0.439856
#   45  -1.110 -1.528785
#   46  -0.040  0.353094
#   47  -4.345 -3.629699
#
#   [112 rows x 2 columns],
#   'el_time': 105.11172890663147,
#   'mean_mse': 0.8169545,
#   'mean_l1': 0.70192987,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 3,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1-2): 2 x GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.460 -2.447136
#   1    0.522  0.884722
#   2   -0.390 -0.251115
#   3   -3.900 -4.528901
#   4   -1.520 -2.852349
#   ..     ...       ...
#   43  -2.210 -2.381886
#   44  -4.470 -3.841414
#   45  -2.380 -2.873748
#   46  -1.370 -1.896574
#   47  -1.110 -1.848587
#
#   [112 rows x 2 columns],
#   'el_time': 138.40194296836853,
#   'mean_mse': 0.6851592,
#   'mean_l1': 0.56547165,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 3,
#   'linear_sizes': [],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1-2): 2 x GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.850 -3.634115
#   1   -3.510 -3.461404
#   2   -7.200 -5.849491
#   3    0.610 -0.897302
#   4   -3.010 -2.655722
#   ..     ...       ...
#   43  -2.210 -2.368828
#   44  -1.110 -2.127891
#   45  -3.220 -3.274567
#   46  -6.291 -6.858654
#   47  -1.520 -3.305919
#
#   [112 rows x 2 columns],
#   'el_time': 105.52938795089722,
#   'mean_mse': 0.6221972,
#   'mean_l1': 0.5834514,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 4,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1-3): 3 x GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.260  0.692254
#   1   -0.030  0.107021
#   2   -0.440 -0.945295
#   3   -5.400 -4.123544
#   4   -1.640 -2.429898
#   ..     ...       ...
#   43   0.790 -0.080429
#   44   0.522 -0.080487
#   45  -9.160 -8.217605
#   46   0.540  0.421497
#   47  -3.927 -0.611492
#
#   [112 rows x 2 columns],
#   'el_time': 147.84335589408875,
#   'mean_mse': 0.7244829,
#   'mean_l1': 0.64732337,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 4,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1-3): 3 x GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    1.100  0.819155
#   1   -1.370 -2.333029
#   2   -3.927 -1.969395
#   3   -6.780 -5.844174
#   4   -1.360 -0.929084
#   ..     ...       ...
#   43  -0.600 -0.628457
#   44   0.620  0.114459
#   45  -2.460 -1.851112
#   46  -1.614 -1.988842
#   47  -3.780 -4.298752
#
#   [112 rows x 2 columns],
#   'el_time': 203.77923941612244,
#   'mean_mse': 0.668376,
#   'mean_l1': 0.6264594,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 4,
#   'linear_sizes': [],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#       (1-3): 3 x GCNConv(256, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=256, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.620 -0.112113
#   1   -3.300 -2.443805
#   2   -0.390 -0.668096
#   3   -4.345 -3.968967
#   4    0.580  0.614924
#   ..     ...       ...
#   43  -1.520 -1.631719
#   44  -3.680 -3.616945
#   45  -5.030 -5.013120
#   46  -2.380 -2.297967
#   47  -5.400 -4.377670
#
#   [112 rows x 2 columns],
#   'el_time': 140.59392189979553,
#   'mean_mse': 0.9870571,
#   'mean_l1': 0.7194864,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 256)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -1.989 -2.651238
#   1   -1.110 -2.152621
#   2   -2.210 -4.430109
#   3   -3.140 -2.546442
#   4    0.260  0.918916
#   ..     ...       ...
#   43  -5.507 -5.450174
#   44  -1.640 -1.105823
#   45  -3.900 -3.636649
#   46  -2.280 -3.318160
#   47  -3.450 -4.772157
#
#   [112 rows x 2 columns],
#   'el_time': 163.30121040344238,
#   'mean_mse': 1.3492749,
#   'mean_l1': 0.87357795,
#   'apply_scaffold_split': False,
#   'hidden_channels': [256],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
# ...
#   'hidden_channels': [512],
#   'gcn_layers': 4,
#   'linear_sizes': [],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-3): 3 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.070 -4.552466
#   1   -0.400 -0.214093
#   2   -3.510 -3.948305
#   3   -4.173 -4.900037
#   4   -1.458 -0.706832
#   ..     ...       ...
#   43  -2.840 -4.566407
#   44  -6.780 -5.620192
#   45   0.260  1.438734
#   46  -3.300 -2.276439
#   47  -1.520 -1.702862
#
#   [112 rows x 2 columns],
#   'el_time': 91.30751037597656,
#   'mean_mse': 1.0200533,
#   'mean_l1': 0.7193129,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -7.420 -6.545705
#   1   -5.240 -5.424177
#   2   -3.083 -3.406290
#   3   -2.080 -3.154916
#   4   -3.510 -3.270498
#   ..     ...       ...
#   43  -2.820 -4.162690
#   44  -1.820 -1.855963
#   45  -0.600 -0.533756
#   46  -2.218 -3.104382
#   47  -4.380 -4.403923
#
#   [112 rows x 2 columns],
#   'el_time': 106.7849326133728,
#   'mean_mse': 1.3474032,
#   'mean_l1': 0.8749409,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -5.400 -4.423716
#   1   -2.070 -3.411102
#   2   -1.640 -3.301022
#   3   -3.680 -4.147175
#   4   -3.796 -3.390226
#   ..     ...       ...
#   43  -2.380 -3.162009
#   44  -5.507 -4.480967
#   45  -3.010 -2.718317
#   46   0.540 -1.509909
#   47  -1.989 -2.741575
#
#   [112 rows x 2 columns],
#   'el_time': 125.43432998657227,
#   'mean_mse': 1.7518237,
#   'mean_l1': 0.90090764,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 1,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.850 -2.885767
#   1   -5.030 -4.483073
#   2   -4.470 -4.180654
#   3   -3.927 -2.207292
#   4   -5.507 -4.978001
#   ..     ...       ...
#   43  -4.310 -4.190160
#   44  -5.240 -4.115090
#   45   0.610 -0.776575
#   46   0.790 -0.388917
#   47  -0.040  0.166900
#
#   [112 rows x 2 columns],
#   'el_time': 117.03499507904053,
#   'mean_mse': 0.45428398,
#   'mean_l1': 0.505999,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 2,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1): GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.770 -3.268169
#   1   -8.400 -5.638814
#   2   -4.310 -4.765988
#   3   -3.460 -3.831173
#   4   -3.927 -2.113782
#   ..     ...       ...
#   43  -3.010 -3.127023
#   44  -3.850 -3.844830
#   45  -1.300 -0.875925
#   46  -3.928 -3.853878
#   47  -2.370 -2.491503
#
#   [112 rows x 2 columns],
#   'el_time': 80.24462461471558,
#   'mean_mse': 0.89252895,
#   'mean_l1': 0.74854934,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 2,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1): GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -3.220 -3.445061
#   1   -3.900 -4.030412
#   2   -4.470 -4.034576
#   3   -2.730 -3.663797
#   4   -1.060 -1.162220
#   ..     ...       ...
#   43  -5.507 -5.078225
#   44  -4.345 -4.668749
#   45  -0.040 -0.106153
#   46  -1.820 -1.692794
#   47  -2.676 -2.932855
#
#   [112 rows x 2 columns],
#   'el_time': 92.99876856803894,
#   'mean_mse': 0.9185901,
#   'mean_l1': 0.6375306,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 2,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1): GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    -3.22 -2.890079
#   1    -3.51 -3.224981
#   2    -3.01 -3.235052
#   3    -7.85 -7.637496
#   4    -3.78 -4.155895
#   ..     ...       ...
#   43   -0.03 -0.386269
#   44   -2.07 -2.952523
#   45   -4.28 -4.431235
#   46    0.54 -0.692246
#   47   -2.77 -3.031724
#
#   [112 rows x 2 columns],
#   'el_time': 166.4134440422058,
#   'mean_mse': 0.72009945,
#   'mean_l1': 0.6185879,
#   'apply_scaffold_split': False,
#   'hidden_channels': [64],
#   'gcn_layers': 4,
#   'linear_sizes': [],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 64)
#       (1-3): 3 x GCNConv(64, 64)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=128, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.430  0.108361
#   1   -5.507 -5.346970
#   2   -1.340 -0.868086
#   3   -0.030  0.106219
#   4   -2.070 -2.957752
#   ..     ...       ...
#   43  -5.240 -4.059479
#   44  -4.173 -4.176983
#   45  -1.730 -1.989735
#   46  -2.460 -2.961754
#   47  -2.210 -2.408046
#
#   [112 rows x 2 columns],
#   'el_time': 77.85707068443298,
#   'mean_mse': 0.5482309,
#   'mean_l1': 0.5467677,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 3,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-2): 2 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -1.989 -2.073768
#   1   -1.340 -1.352510
#   2   -1.520 -3.474852
#   3   -0.390 -0.832923
#   4   -0.807 -0.707556
#   ..     ...       ...
#   43  -3.680 -3.992538
#   44  -2.080 -2.990232
#   45  -6.780 -5.483593
#   46   0.580  0.400623
#   47  -2.560 -2.652472
#
#   [112 rows x 2 columns],
#   'el_time': 64.29855585098267,
#   'mean_mse': 0.74092054,
#   'mean_l1': 0.6564499,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 3,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-2): 2 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.009 -0.593564
#   1   -4.470 -4.143744
#   2   -3.460 -4.579031
#   3   -1.990 -1.654600
#   4   -7.420 -8.148437
#   ..     ...       ...
#   43  -1.300 -1.866163
#   44  -1.110 -1.779801
#   45  -3.900 -4.377522
#   46  -3.010 -2.776559
#   47  -1.360 -0.729877
#
#   [112 rows x 2 columns],
#   'el_time': 87.52157402038574,
#   'mean_mse': 0.6583067,
#   'mean_l1': 0.57115865,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 3,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-2): 2 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0     0.79 -0.108984
#   1    -2.28 -3.732426
#   2     0.51  0.056993
#   3    -3.78 -3.505213
#   4    -2.21 -2.266692
#   ..     ...       ...
#   43   -9.16 -9.254159
#   44   -3.46 -4.792680
#   45   -2.56 -2.621932
#   46    0.62  0.141774
#   47   -7.42 -8.105555
#
#   [112 rows x 2 columns],
#   'el_time': 98.0713107585907,
#   'mean_mse': 0.6667874,
#   'mean_l1': 0.5927997,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 4,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-3): 3 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    0.580  0.488099
#   1   -0.807 -1.180700
#   2   -2.730 -3.656198
#   3   -3.796 -3.652885
#   4   -3.900 -4.028680
#   ..     ...       ...
#   43  -6.291 -5.371792
#   44  -3.927 -1.247217
#   45  -5.507 -5.545019
#   46  -2.210 -1.561518
#   47  -2.676 -2.299086
#
#   [112 rows x 2 columns],
#   'el_time': 55.79505777359009,
#   'mean_mse': 0.71534884,
#   'mean_l1': 0.62800914,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 4,
#   'linear_sizes': [512],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-3): 3 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -1.614 -1.668496
#   1   -0.040 -0.137008
#   2   -4.799 -2.324299
#   3   -3.100 -2.270831
#   4   -4.110 -3.971401
#   ..     ...       ...
#   43  -5.400 -4.794061
#   44  -3.140 -2.644034
#   45  -9.160 -8.985961
#   46  -2.630 -2.634418
#   47  -0.400  0.182322
#
#   [112 rows x 2 columns],
#   'el_time': 86.86547660827637,
#   'mean_mse': 0.8366539,
#   'mean_l1': 0.6395767,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 4,
#   'linear_sizes': [512],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1-3): 3 x GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.440 -0.497923
#   1   -5.240 -4.879741
#   2   -4.370 -2.729933
#   3   -1.110 -2.158751
#   4   -2.630 -3.656385
#   ..     ...       ...
#   43  -3.460 -2.537333
#   44  -2.840 -4.296029
#   45  -2.560 -1.963191
#   46  -5.115 -4.212612
#   47  -6.250 -5.942770
#
#   [112 rows x 2 columns],
#   'el_time': 92.38722014427185,
#   'mean_mse': 1.0029768,
#   'mean_l1': 0.7105205,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 1,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -0.720 -2.585973
#   1   -2.550 -3.033597
#   2   -0.360  0.343205
#   3   -1.520 -4.188605
#   4   -2.280 -3.383796
#   ..     ...       ...
#   43  -1.458 -1.120184
#   44  -4.380 -4.467763
#   45  -3.796 -3.832182
#   46  -2.420 -4.252510
#   47  -3.900 -3.543266
#
#   [112 rows x 2 columns],
#   'el_time': 128.14434051513672,
#   'mean_mse': 1.2641941,
#   'mean_l1': 0.84502506,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 1,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0    -3.10 -3.080182
#   1    -1.52 -2.549077
#   2    -2.84 -3.922997
#   3    -2.00 -1.970571
#   4    -6.25 -6.224980
#   ..     ...       ...
#   43   -2.28 -1.689349
#   44   -0.39 -1.618493
#   45   -2.46 -1.843965
#   46   -4.92 -3.283557
#   47   -2.73 -5.034386
#
#   [112 rows x 2 columns],
#   'el_time': 106.95481634140015,
#   'mean_mse': 1.7765185,
#   'mean_l1': 0.92912304,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 1,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=512, out_features=1, bias=True)
#   )},
#  {'pred_df':     y_real    y_pred
#   0   -2.218 -2.679187
#   1   -3.450 -4.198439
#   2   -3.780 -4.109572
#   3   -2.210 -1.024773
#   4   -3.100 -2.813378
#   ..     ...       ...
#   43  -1.220 -2.124566
#   44  -1.060 -0.912343
#   45  -3.510 -3.405714
#   46   0.790 -0.978266
#   47  -3.460 -3.273428
#
#   [112 rows x 2 columns],
#   'el_time': 53.863465547561646,
#   'mean_mse': 0.67093575,
#   'mean_l1': 0.59099644,
#   'apply_scaffold_split': False,
#   'hidden_channels': [512],
#   'gcn_layers': 2,
#   'linear_sizes': [512, 256],
#   'aggregations': ['global_mean_pool', 'global_max_pool'],
#   'apply_random_aggregations': False,
#   'learning_rate': 0.001,
#   'model_type': 'GNN',
#   'model': GCN_molecule_regression(
#     (convs): ModuleList(
#       (0): GCNConv(9, 512)
#       (1): GCNConv(512, 512)
#     )
#     (activation1): ReLU()
#     (activation2): ReLU()
#     (additional_layers): ModuleList()
#     (out): Linear(in_features=1024, out_features=1, bias=True)
#   )}]

# %%
ff = file1_load[0]

# %%
ff
# Out:
# {'pred_df':     y_real    y_pred
#  0    -3.85 -4.088128
#  1     0.79 -0.508802
#  2    -1.82 -2.222143
#  3    -1.73 -2.840542
#  4    -3.40 -3.117310
#  ..     ...       ...
#  43   -5.03 -4.832994
#  44   -7.85 -6.906616
#  45   -7.42 -7.309327
#  46   -5.24 -4.641108
#  47   -3.10 -2.841666
#
#  [112 rows x 2 columns],
#  'el_time': 151.7859513759613,
#  'mean_mse': 1.1591473,
#  'mean_l1': 0.7628732,
#  'apply_scaffold_split': False,
#  'hidden_channels': [64],
#  'gcn_layers': 1,
#  'linear_sizes': [],
#  'aggregations': ['global_mean_pool', 'global_max_pool'],
#  'apply_random_aggregations': False,
#  'learning_rate': 0.001,
#  'model_type': 'GNN',
#  'model': GCN_molecule_regression(
#    (convs): ModuleList(
#      (0): GCNConv(9, 64)
#    )
#    (activation1): ReLU()
#    (activation2): ReLU()
#    (additional_layers): ModuleList()
#    (out): Linear(in_features=128, out_features=1, bias=True)
#  )}

# %%
ff["pred_df"]
# Out:
#     y_real    y_pred
# 0    -3.85 -4.088128
# 1     0.79 -0.508802
# 2    -1.82 -2.222143
# 3    -1.73 -2.840542
# 4    -3.40 -3.117310
# ..     ...       ...
# 43   -5.03 -4.832994
# 44   -7.85 -6.906616
# 45   -7.42 -7.309327
# 46   -5.24 -4.641108
# 47   -3.10 -2.841666
#
# [112 rows x 2 columns]

# %%
ff
# Out:
# {'pred_df':     y_real    y_pred
#  0    -3.85 -4.088128
#  1     0.79 -0.508802
#  2    -1.82 -2.222143
#  3    -1.73 -2.840542
#  4    -3.40 -3.117310
#  ..     ...       ...
#  43   -5.03 -4.832994
#  44   -7.85 -6.906616
#  45   -7.42 -7.309327
#  46   -5.24 -4.641108
#  47   -3.10 -2.841666
#
#  [112 rows x 2 columns],
#  'el_time': 151.7859513759613,
#  'mean_mse': 1.1591473,
#  'mean_l1': 0.7628732,
#  'apply_scaffold_split': False,
#  'hidden_channels': [64],
#  'gcn_layers': 1,
#  'linear_sizes': [],
#  'aggregations': ['global_mean_pool', 'global_max_pool'],
#  'apply_random_aggregations': False,
#  'learning_rate': 0.001,
#  'model_type': 'GNN',
#  'model': GCN_molecule_regression(
#    (convs): ModuleList(
#      (0): GCNConv(9, 64)
#    )
#    (activation1): ReLU()
#    (activation2): ReLU()
#    (additional_layers): ModuleList()
#    (out): Linear(in_features=128, out_features=1, bias=True)
#  )}

# %%
keys_to_extract = ['hidden_channels', 'gcn_layers', 'linear_sizes', 'aggregations']

plot1 = []
for run in file1_load:
    lossvalue_mse = run["mean_mse"]
    lossvalue_l1 = run["mean_l1"]
    
    extracted_dict = {key: run[key] for key in keys_to_extract if key in run}
    extracted_dict["lossvalue_mse"] = lossvalue_mse
    extracted_dict["lossvalue_l1"] = lossvalue_l1
    df = pd.DataFrame([extracted_dict])
    #plot1.append([lossvalue, df])
    plot1.append(df)

# %%
plot1
# Out:
# [  hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           1           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.159147      0.762873  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           1           []  [global_mean_pool]        1.87995
#
#     lossvalue_l1
#  0      1.085678  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           4           []  [global_mean_pool]       0.749703
#
#     lossvalue_l1
#  0      0.661114  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           2   [512, 256]  [global_mean_pool]       0.764355
#
#     lossvalue_l1
#  0      0.695703  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           2   [512, 256]  [global_max_pool]        0.92707
#
#     lossvalue_l1
#  0      0.659493  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           3   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.507662      0.511903  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           3   [512, 256]  [global_mean_pool]       0.635613
#
#     lossvalue_l1
#  0      0.595348  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           3   [512, 256]  [global_max_pool]       0.730111
#
#     lossvalue_l1
#  0      0.601707  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           4   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.702078      0.619766  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           4   [512, 256]  [global_mean_pool]       0.625519
#
#     lossvalue_l1
#  0      0.603751  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           4   [512, 256]  [global_max_pool]       0.782813
#
#     lossvalue_l1
#  0      0.639094  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           4           []  [global_max_pool]       0.746323
#
#     lossvalue_l1
#  0      0.633061  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           1        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.004835      0.724967  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           1        [512]  [global_mean_pool]       1.998819
#
#     lossvalue_l1
#  0      1.111967  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           1        [512]  [global_max_pool]       1.955811
#
#     lossvalue_l1
#  0      0.983729  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           2        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.032611      0.739675  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           2        [512]  [global_mean_pool]       1.216218
#
#     lossvalue_l1
#  0      0.836742  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           2        [512]  [global_max_pool]       1.343743
#
#     lossvalue_l1
#  0      0.897272  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           3        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.845349      0.681427  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           3        [512]  [global_mean_pool]       0.817177
#
#     lossvalue_l1
#  0      0.713913  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           1           []  [global_max_pool]       1.892769
#
#     lossvalue_l1
#  0       0.98083  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           3        [512]  [global_max_pool]       0.715998
#
#     lossvalue_l1
#  0      0.597116  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           4        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.725737       0.65391  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           4        [512]  [global_mean_pool]       0.812334
#
#     lossvalue_l1
#  0       0.67957  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           4        [512]  [global_max_pool]       0.807926
#
#     lossvalue_l1
#  0      0.641106  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           1   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.139992      0.790107  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           1   [512, 256]  [global_mean_pool]       2.320485
#
#     lossvalue_l1
#  0      1.229188  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           1   [512, 256]  [global_max_pool]       2.144246
#
#     lossvalue_l1
#  0      1.135082  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           2   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.766579      0.642472  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           2   [512, 256]  [global_mean_pool]       1.204106
#
#     lossvalue_l1
#  0      0.836429  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           2   [512, 256]  [global_max_pool]        1.21406
#
#     lossvalue_l1
#  0      0.793913  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           2           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.733485       0.64064  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           3   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.071418      0.759657  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           3   [512, 256]  [global_mean_pool]       1.031367
#
#     lossvalue_l1
#  0      0.786024  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           3   [512, 256]  [global_max_pool]       0.666648
#
#     lossvalue_l1
#  0      0.587391  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           4   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.671711      0.627676  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           4   [512, 256]  [global_mean_pool]       0.842818
#
#     lossvalue_l1
#  0      0.703656  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           4   [512, 256]  [global_max_pool]       0.703264
#
#     lossvalue_l1
#  0      0.612638  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           1           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.333792      0.854193  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           1           []  [global_mean_pool]       1.475654
#
#     lossvalue_l1
#  0      0.928847  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           1           []  [global_max_pool]       1.794586
#
#     lossvalue_l1
#  0       0.96565  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           2           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.632834      0.601812  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           2           []  [global_mean_pool]        1.12271
#
#     lossvalue_l1
#  0      0.807854  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           2           []  [global_mean_pool]       0.998963
#
#     lossvalue_l1
#  0      0.766358  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           2           []  [global_max_pool]       0.964302
#
#     lossvalue_l1
#  0       0.65221  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           3           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.662569      0.586409  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           3           []  [global_mean_pool]       0.816954
#
#     lossvalue_l1
#  0       0.70193  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           3           []  [global_max_pool]       0.685159
#
#     lossvalue_l1
#  0      0.565472  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           4           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.622197      0.583451  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           4           []  [global_mean_pool]       0.724483
#
#     lossvalue_l1
#  0      0.647323  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           4           []  [global_max_pool]       0.668376
#
#     lossvalue_l1
#  0      0.626459  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           1        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.987057      0.719486  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           1        [512]  [global_mean_pool]       1.349275
#
#     lossvalue_l1
#  0      0.873578  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           2           []  [global_max_pool]       1.242419
#
#     lossvalue_l1
#  0      0.788718  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           1        [512]  [global_max_pool]       1.644605
#
#     lossvalue_l1
#  0      0.928234  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           2        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.655926       0.57107  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           2        [512]  [global_mean_pool]       1.045301
#
#     lossvalue_l1
#  0      0.795555  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           2        [512]  [global_max_pool]       0.983705
#
#     lossvalue_l1
#  0      0.658819  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           3        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.568955      0.554658  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           3        [512]  [global_mean_pool]       0.691752
#
#     lossvalue_l1
#  0      0.652792  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           3        [512]  [global_max_pool]       0.682665
#
#     lossvalue_l1
#  0      0.575683  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           4        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.695505      0.622417  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           4        [512]  [global_mean_pool]       0.739295
#
#     lossvalue_l1
#  0      0.658176  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           4        [512]  [global_max_pool]       0.707998
#
#     lossvalue_l1
#  0      0.594951  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           3           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.670306      0.598521  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           1   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.917204      0.697242  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           1   [512, 256]  [global_mean_pool]       1.457952
#
#     lossvalue_l1
#  0       0.92945  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           1   [512, 256]  [global_max_pool]       1.761517
#
#     lossvalue_l1
#  0      0.949008  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           2   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.586896      0.566953  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           2   [512, 256]  [global_mean_pool]       0.984079
#
#     lossvalue_l1
#  0      0.743549  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           2   [512, 256]  [global_max_pool]       1.129797
#
#     lossvalue_l1
#  0      0.705835  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           3   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.543321      0.533611  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           3   [512, 256]  [global_mean_pool]       0.670078
#
#     lossvalue_l1
#  0      0.625256  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           3   [512, 256]  [global_max_pool]       0.737036
#
#     lossvalue_l1
#  0       0.61815  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [256]           4   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.547392      0.551128  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0            [64]           3           []  [global_mean_pool]       0.860759
#
#     lossvalue_l1
#  0      0.714411  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [256]           4   [512, 256]  [global_mean_pool]       0.632519
#
#     lossvalue_l1
#  0      0.588585  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [256]           4   [512, 256]  [global_max_pool]       0.726065
#
#     lossvalue_l1
#  0      0.615329  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           1           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.838546       0.64429  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           1           []  [global_mean_pool]        1.33947
#
#     lossvalue_l1
#  0      0.872475  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           1           []  [global_max_pool]       1.695134
#
#     lossvalue_l1
#  0       0.92443  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           2           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.470886      0.514185  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           2           []  [global_mean_pool]       0.900645
#
#     lossvalue_l1
#  0      0.760998  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           2           []  [global_max_pool]       0.909152
#
#     lossvalue_l1
#  0      0.619027  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           3           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.540469      0.520313  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           3           []  [global_mean_pool]       0.738299
#
#     lossvalue_l1
#  0      0.679986  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0            [64]           3           []  [global_max_pool]       1.077926
#
#     lossvalue_l1
#  0      0.769036  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           3           []  [global_max_pool]       0.692947
#
#     lossvalue_l1
#  0      0.580446  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           4           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.599237      0.575865  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           4           []  [global_mean_pool]       0.576426
#
#     lossvalue_l1
#  0      0.568877  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           4           []  [global_max_pool]       0.796039
#
#     lossvalue_l1
#  0      0.643134  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           1        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.020053      0.719313  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           1        [512]  [global_mean_pool]       1.347403
#
#     lossvalue_l1
#  0      0.874941  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           1        [512]  [global_max_pool]       1.751824
#
#     lossvalue_l1
#  0      0.900908  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           2        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.454284      0.505999  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           2        [512]  [global_mean_pool]       0.892529
#
#     lossvalue_l1
#  0      0.748549  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           2        [512]  [global_max_pool]        0.91859
#
#     lossvalue_l1
#  0      0.637531  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0            [64]           4           []
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.720099      0.618588  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           3        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.548231      0.546768  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           3        [512]  [global_mean_pool]       0.740921
#
#     lossvalue_l1
#  0       0.65645  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           3        [512]  [global_max_pool]       0.658307
#
#     lossvalue_l1
#  0      0.571159  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           4        [512]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.666787        0.5928  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           4        [512]  [global_mean_pool]       0.715349
#
#     lossvalue_l1
#  0      0.628009  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           4        [512]  [global_max_pool]       0.836654
#
#     lossvalue_l1
#  0      0.639577  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           1   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       1.002977      0.710521  ,
#    hidden_channels  gcn_layers linear_sizes        aggregations  lossvalue_mse  \
#  0           [512]           1   [512, 256]  [global_mean_pool]       1.264194
#
#     lossvalue_l1
#  0      0.845025  ,
#    hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
#  0           [512]           1   [512, 256]  [global_max_pool]       1.776518
#
#     lossvalue_l1
#  0      0.929123  ,
#    hidden_channels  gcn_layers linear_sizes  \
#  0           [512]           2   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
#  0  [global_mean_pool, global_max_pool]       0.670936      0.590996  ]

# %%
plot1[4]
# Out:
#   hidden_channels  gcn_layers linear_sizes       aggregations  lossvalue_mse  \
# 0           [512]           2   [512, 256]  [global_max_pool]        0.92707
#
#    lossvalue_l1
# 0      0.659493

# %%
fullplot1 = pd.concat(plot1)

# %%
fullplot1
# Out:
#    hidden_channels  gcn_layers linear_sizes  \
# 0             [64]           1           []
# 0             [64]           1           []
# 0             [64]           4           []
# 0            [512]           2   [512, 256]
# 0            [512]           2   [512, 256]
# ..             ...         ...          ...
# 0            [512]           4        [512]
# 0            [512]           1   [512, 256]
# 0            [512]           1   [512, 256]
# 0            [512]           1   [512, 256]
# 0            [512]           2   [512, 256]
#
#                            aggregations  lossvalue_mse  lossvalue_l1
# 0   [global_mean_pool, global_max_pool]       1.159147      0.762873
# 0                    [global_mean_pool]       1.879950      1.085678
# 0                    [global_mean_pool]       0.749703      0.661114
# 0                    [global_mean_pool]       0.764355      0.695703
# 0                     [global_max_pool]       0.927070      0.659493
# ..                                  ...            ...           ...
# 0                     [global_max_pool]       0.836654      0.639577
# 0   [global_mean_pool, global_max_pool]       1.002977      0.710521
# 0                    [global_mean_pool]       1.264194      0.845025
# 0                     [global_max_pool]       1.776518      0.929123
# 0   [global_mean_pool, global_max_pool]       0.670936      0.590996
#
# [108 rows x 6 columns]

# %%
fullplot1['linear_sizes'].astype(str)
# Out:
# 0            []
# 0            []
# 0            []
# 0    [512, 256]
# 0    [512, 256]
#         ...
# 0         [512]
# 0    [512, 256]
# 0    [512, 256]
# 0    [512, 256]
# 0    [512, 256]
# Name: linear_sizes, Length: 108, dtype: object

# %%
fullplot1['aggregations'].astype(str)
# Out:
# 0    ['global_mean_pool', 'global_max_pool']
# 0                       ['global_mean_pool']
# 0                       ['global_mean_pool']
# 0                       ['global_mean_pool']
# 0                        ['global_max_pool']
#                       ...
# 0                        ['global_max_pool']
# 0    ['global_mean_pool', 'global_max_pool']
# 0                       ['global_mean_pool']
# 0                        ['global_max_pool']
# 0    ['global_mean_pool', 'global_max_pool']
# Name: aggregations, Length: 108, dtype: object

# %%
fullplot1.drop(columns="lossvalue_mse", axis=0)
# Out:
#    hidden_channels  gcn_layers linear_sizes  \
# 0             [64]           1           []
# 0             [64]           1           []
# 0             [64]           4           []
# 0            [512]           2   [512, 256]
# 0            [512]           2   [512, 256]
# ..             ...         ...          ...
# 0            [512]           4        [512]
# 0            [512]           1   [512, 256]
# 0            [512]           1   [512, 256]
# 0            [512]           1   [512, 256]
# 0            [512]           2   [512, 256]
#
#                            aggregations  lossvalue_l1
# 0   [global_mean_pool, global_max_pool]      0.762873
# 0                    [global_mean_pool]      1.085678
# 0                    [global_mean_pool]      0.661114
# 0                    [global_mean_pool]      0.695703
# 0                     [global_max_pool]      0.659493
# ..                                  ...           ...
# 0                     [global_max_pool]      0.639577
# 0   [global_mean_pool, global_max_pool]      0.710521
# 0                    [global_mean_pool]      0.845025
# 0                     [global_max_pool]      0.929123
# 0   [global_mean_pool, global_max_pool]      0.590996
#
# [108 rows x 5 columns]

# %%
fullplot1["lossvalue_mse"]
# Out:
# 0    1.159147
# 0    1.879950
# 0    0.749703
# 0    0.764355
# 0    0.927070
#        ...
# 0    0.836654
# 0    1.002977
# 0    1.264194
# 0    1.776518
# 0    0.670936
# Name: lossvalue_mse, Length: 108, dtype: float32

# %%
fullplot1['Combined Label'] = fullplot1.drop(columns=["lossvalue_mse", "lossvalue_l1"], axis=1).astype(str).agg(' - '.join, axis=1)

# %%
pd.set_option('display.max_rows', 200)

# %%
fullplot1.sort_values(by=['lossvalue_mse'])
# Out:
#   hidden_channels  gcn_layers linear_sizes  \
# 0           [512]           2        [512]
# 0           [512]           2           []
# 0           [512]           3   [512, 256]
# 0           [512]           3           []
# 0           [256]           3   [512, 256]
# 0           [256]           4   [512, 256]
# 0           [512]           3        [512]
# 0           [256]           3        [512]
# 0           [512]           4           []
# 0           [256]           2   [512, 256]
# 0           [512]           4           []
# 0           [256]           4           []
# 0           [512]           4   [512, 256]
# 0           [256]           4   [512, 256]
# 0           [256]           2           []
# 0           [512]           3   [512, 256]
# 0           [256]           2        [512]
# 0           [512]           3        [512]
# 0           [256]           3           []
# 0            [64]           3   [512, 256]
# 0           [512]           4        [512]
# 0           [256]           4           []
# 0           [256]           3   [512, 256]
# 0            [64]           3           []
# 0           [512]           2   [512, 256]
# 0            [64]           4   [512, 256]
# 0           [256]           3        [512]
# 0           [256]           3           []
# 0           [256]           3        [512]
# 0           [512]           3           []
# 0           [256]           4        [512]
# 0           [512]           4   [512, 256]
# 0            [64]           4   [512, 256]
# 0           [256]           4        [512]
# 0           [512]           4        [512]
# 0            [64]           3        [512]
# 0            [64]           4           []
# 0           [256]           4           []
# 0            [64]           4        [512]
# 0           [256]           4   [512, 256]
# 0           [512]           3   [512, 256]
# 0            [64]           2           []
# 0           [256]           3   [512, 256]
# 0           [512]           3           []
# 0           [256]           4        [512]
# 0           [512]           3        [512]
# 0            [64]           4           []
# 0            [64]           4           []
# 0           [512]           2   [512, 256]
# 0            [64]           2   [512, 256]
# 0           [512]           4   [512, 256]
# 0           [512]           4           []
# 0            [64]           4        [512]
# 0            [64]           4        [512]
# 0           [256]           3           []
# 0            [64]           3        [512]
# 0           [512]           4        [512]
# 0           [512]           1           []
# 0            [64]           4   [512, 256]
# 0            [64]           3        [512]
# 0            [64]           3           []
# 0           [512]           2        [512]
# 0           [512]           2           []
# 0           [512]           2           []
# 0           [256]           1   [512, 256]
# 0           [512]           2        [512]
# 0           [512]           2   [512, 256]
# 0           [256]           2           []
# 0           [256]           2        [512]
# 0           [256]           2   [512, 256]
# 0           [256]           1        [512]
# 0           [256]           2           []
# 0           [512]           1   [512, 256]
# 0            [64]           1        [512]
# 0           [512]           1        [512]
# 0            [64]           3   [512, 256]
# 0            [64]           2        [512]
# 0           [256]           2        [512]
# 0            [64]           3   [512, 256]
# 0            [64]           3           []
# 0            [64]           2           []
# 0           [256]           2   [512, 256]
# 0            [64]           1   [512, 256]
# 0            [64]           1           []
# 0            [64]           2   [512, 256]
# 0            [64]           2   [512, 256]
# 0            [64]           2        [512]
# 0            [64]           2           []
# 0           [512]           1   [512, 256]
# 0           [256]           1           []
# 0           [512]           1           []
# 0            [64]           2        [512]
# 0           [512]           1        [512]
# 0           [256]           1        [512]
# 0           [256]           1   [512, 256]
# 0           [256]           1           []
# 0           [256]           1        [512]
# 0           [512]           1           []
# 0           [512]           1        [512]
# 0           [256]           1   [512, 256]
# 0           [512]           1   [512, 256]
# 0           [256]           1           []
# 0            [64]           1           []
# 0            [64]           1           []
# 0            [64]           1        [512]
# 0            [64]           1        [512]
# 0            [64]           1   [512, 256]
# 0            [64]           1   [512, 256]
#
#                           aggregations  lossvalue_mse  lossvalue_l1  \
# 0  [global_mean_pool, global_max_pool]       0.454284      0.505999
# 0  [global_mean_pool, global_max_pool]       0.470886      0.514185
# 0  [global_mean_pool, global_max_pool]       0.507662      0.511903
# 0  [global_mean_pool, global_max_pool]       0.540469      0.520313
# 0  [global_mean_pool, global_max_pool]       0.543321      0.533611
# 0  [global_mean_pool, global_max_pool]       0.547392      0.551128
# 0  [global_mean_pool, global_max_pool]       0.548231      0.546768
# 0  [global_mean_pool, global_max_pool]       0.568955      0.554658
# 0                   [global_mean_pool]       0.576426      0.568877
# 0  [global_mean_pool, global_max_pool]       0.586896      0.566953
# 0  [global_mean_pool, global_max_pool]       0.599237      0.575865
# 0  [global_mean_pool, global_max_pool]       0.622197      0.583451
# 0                   [global_mean_pool]       0.625519      0.603751
# 0                   [global_mean_pool]       0.632519      0.588585
# 0  [global_mean_pool, global_max_pool]       0.632834      0.601812
# 0                   [global_mean_pool]       0.635613      0.595348
# 0  [global_mean_pool, global_max_pool]       0.655926      0.571070
# 0                    [global_max_pool]       0.658307      0.571159
# 0  [global_mean_pool, global_max_pool]       0.662569      0.586409
# 0                    [global_max_pool]       0.666648      0.587391
# 0  [global_mean_pool, global_max_pool]       0.666787      0.592800
# 0                    [global_max_pool]       0.668376      0.626459
# 0                   [global_mean_pool]       0.670078      0.625256
# 0  [global_mean_pool, global_max_pool]       0.670306      0.598521
# 0  [global_mean_pool, global_max_pool]       0.670936      0.590996
# 0  [global_mean_pool, global_max_pool]       0.671711      0.627676
# 0                    [global_max_pool]       0.682665      0.575683
# 0                    [global_max_pool]       0.685159      0.565472
# 0                   [global_mean_pool]       0.691752      0.652792
# 0                    [global_max_pool]       0.692947      0.580446
# 0  [global_mean_pool, global_max_pool]       0.695505      0.622417
# 0  [global_mean_pool, global_max_pool]       0.702078      0.619766
# 0                    [global_max_pool]       0.703264      0.612638
# 0                    [global_max_pool]       0.707998      0.594951
# 0                   [global_mean_pool]       0.715349      0.628009
# 0                    [global_max_pool]       0.715998      0.597116
# 0  [global_mean_pool, global_max_pool]       0.720099      0.618588
# 0                   [global_mean_pool]       0.724483      0.647323
# 0  [global_mean_pool, global_max_pool]       0.725737      0.653910
# 0                    [global_max_pool]       0.726065      0.615329
# 0                    [global_max_pool]       0.730111      0.601707
# 0  [global_mean_pool, global_max_pool]       0.733485      0.640640
# 0                    [global_max_pool]       0.737036      0.618150
# 0                   [global_mean_pool]       0.738299      0.679986
# 0                   [global_mean_pool]       0.739295      0.658176
# 0                   [global_mean_pool]       0.740921      0.656450
# 0                    [global_max_pool]       0.746323      0.633061
# 0                   [global_mean_pool]       0.749703      0.661114
# 0                   [global_mean_pool]       0.764355      0.695703
# 0  [global_mean_pool, global_max_pool]       0.766579      0.642472
# 0                    [global_max_pool]       0.782813      0.639094
# 0                    [global_max_pool]       0.796039      0.643134
# 0                    [global_max_pool]       0.807926      0.641106
# 0                   [global_mean_pool]       0.812334      0.679570
# 0                   [global_mean_pool]       0.816954      0.701930
# 0                   [global_mean_pool]       0.817177      0.713913
# 0                    [global_max_pool]       0.836654      0.639577
# 0  [global_mean_pool, global_max_pool]       0.838546      0.644290
# 0                   [global_mean_pool]       0.842818      0.703656
# 0  [global_mean_pool, global_max_pool]       0.845349      0.681427
# 0                   [global_mean_pool]       0.860759      0.714411
# 0                   [global_mean_pool]       0.892529      0.748549
# 0                   [global_mean_pool]       0.900645      0.760998
# 0                    [global_max_pool]       0.909152      0.619027
# 0  [global_mean_pool, global_max_pool]       0.917204      0.697242
# 0                    [global_max_pool]       0.918590      0.637531
# 0                    [global_max_pool]       0.927070      0.659493
# 0                    [global_max_pool]       0.964302      0.652210
# 0                    [global_max_pool]       0.983705      0.658819
# 0                   [global_mean_pool]       0.984079      0.743549
# 0  [global_mean_pool, global_max_pool]       0.987057      0.719486
# 0                   [global_mean_pool]       0.998963      0.766358
# 0  [global_mean_pool, global_max_pool]       1.002977      0.710521
# 0  [global_mean_pool, global_max_pool]       1.004835      0.724967
# 0  [global_mean_pool, global_max_pool]       1.020053      0.719313
# 0                   [global_mean_pool]       1.031367      0.786024
# 0  [global_mean_pool, global_max_pool]       1.032611      0.739675
# 0                   [global_mean_pool]       1.045301      0.795555
# 0  [global_mean_pool, global_max_pool]       1.071418      0.759657
# 0                    [global_max_pool]       1.077926      0.769036
# 0                   [global_mean_pool]       1.122710      0.807854
# 0                    [global_max_pool]       1.129797      0.705835
# 0  [global_mean_pool, global_max_pool]       1.139992      0.790107
# 0  [global_mean_pool, global_max_pool]       1.159147      0.762873
# 0                   [global_mean_pool]       1.204106      0.836429
# 0                    [global_max_pool]       1.214060      0.793913
# 0                   [global_mean_pool]       1.216218      0.836742
# 0                    [global_max_pool]       1.242419      0.788718
# 0                   [global_mean_pool]       1.264194      0.845025
# 0  [global_mean_pool, global_max_pool]       1.333792      0.854193
# 0                   [global_mean_pool]       1.339470      0.872475
# 0                    [global_max_pool]       1.343743      0.897272
# 0                   [global_mean_pool]       1.347403      0.874941
# 0                   [global_mean_pool]       1.349275      0.873578
# 0                   [global_mean_pool]       1.457952      0.929450
# 0                   [global_mean_pool]       1.475654      0.928847
# 0                    [global_max_pool]       1.644605      0.928234
# 0                    [global_max_pool]       1.695134      0.924430
# 0                    [global_max_pool]       1.751824      0.900908
# 0                    [global_max_pool]       1.761517      0.949008
# 0                    [global_max_pool]       1.776518      0.929123
# 0                    [global_max_pool]       1.794586      0.965650
# 0                   [global_mean_pool]       1.879950      1.085678
# 0                    [global_max_pool]       1.892769      0.980830
# 0                    [global_max_pool]       1.955811      0.983729
# 0                   [global_mean_pool]       1.998819      1.111967
# 0                    [global_max_pool]       2.144246      1.135082
# 0                   [global_mean_pool]       2.320485      1.229188
#
#                                       Combined Label
# 0  [512] - 2 - [512] - ['global_mean_pool', 'glob...
# 0  [512] - 2 - [] - ['global_mean_pool', 'global_...
# 0  [512] - 3 - [512, 256] - ['global_mean_pool', ...
# 0  [512] - 3 - [] - ['global_mean_pool', 'global_...
# 0  [256] - 3 - [512, 256] - ['global_mean_pool', ...
# 0  [256] - 4 - [512, 256] - ['global_mean_pool', ...
# 0  [512] - 3 - [512] - ['global_mean_pool', 'glob...
# 0  [256] - 3 - [512] - ['global_mean_pool', 'glob...
# 0              [512] - 4 - [] - ['global_mean_pool']
# 0  [256] - 2 - [512, 256] - ['global_mean_pool', ...
# 0  [512] - 4 - [] - ['global_mean_pool', 'global_...
# 0  [256] - 4 - [] - ['global_mean_pool', 'global_...
# 0      [512] - 4 - [512, 256] - ['global_mean_pool']
# 0      [256] - 4 - [512, 256] - ['global_mean_pool']
# 0  [256] - 2 - [] - ['global_mean_pool', 'global_...
# 0      [512] - 3 - [512, 256] - ['global_mean_pool']
# 0  [256] - 2 - [512] - ['global_mean_pool', 'glob...
# 0            [512] - 3 - [512] - ['global_max_pool']
# 0  [256] - 3 - [] - ['global_mean_pool', 'global_...
# 0        [64] - 3 - [512, 256] - ['global_max_pool']
# 0  [512] - 4 - [512] - ['global_mean_pool', 'glob...
# 0               [256] - 4 - [] - ['global_max_pool']
# 0      [256] - 3 - [512, 256] - ['global_mean_pool']
# 0  [64] - 3 - [] - ['global_mean_pool', 'global_m...
# 0  [512] - 2 - [512, 256] - ['global_mean_pool', ...
# 0  [64] - 4 - [512, 256] - ['global_mean_pool', '...
# 0            [256] - 3 - [512] - ['global_max_pool']
# 0               [256] - 3 - [] - ['global_max_pool']
# 0           [256] - 3 - [512] - ['global_mean_pool']
# 0               [512] - 3 - [] - ['global_max_pool']
# 0  [256] - 4 - [512] - ['global_mean_pool', 'glob...
# 0  [512] - 4 - [512, 256] - ['global_mean_pool', ...
# 0        [64] - 4 - [512, 256] - ['global_max_pool']
# 0            [256] - 4 - [512] - ['global_max_pool']
# 0           [512] - 4 - [512] - ['global_mean_pool']
# 0             [64] - 3 - [512] - ['global_max_pool']
# 0  [64] - 4 - [] - ['global_mean_pool', 'global_m...
# 0              [256] - 4 - [] - ['global_mean_pool']
# 0  [64] - 4 - [512] - ['global_mean_pool', 'globa...
# 0       [256] - 4 - [512, 256] - ['global_max_pool']
# 0       [512] - 3 - [512, 256] - ['global_max_pool']
# 0  [64] - 2 - [] - ['global_mean_pool', 'global_m...
# 0       [256] - 3 - [512, 256] - ['global_max_pool']
# 0              [512] - 3 - [] - ['global_mean_pool']
# 0           [256] - 4 - [512] - ['global_mean_pool']
# 0           [512] - 3 - [512] - ['global_mean_pool']
# 0                [64] - 4 - [] - ['global_max_pool']
# 0               [64] - 4 - [] - ['global_mean_pool']
# 0      [512] - 2 - [512, 256] - ['global_mean_pool']
# 0  [64] - 2 - [512, 256] - ['global_mean_pool', '...
# 0       [512] - 4 - [512, 256] - ['global_max_pool']
# 0               [512] - 4 - [] - ['global_max_pool']
# 0             [64] - 4 - [512] - ['global_max_pool']
# 0            [64] - 4 - [512] - ['global_mean_pool']
# 0              [256] - 3 - [] - ['global_mean_pool']
# 0            [64] - 3 - [512] - ['global_mean_pool']
# 0            [512] - 4 - [512] - ['global_max_pool']
# 0  [512] - 1 - [] - ['global_mean_pool', 'global_...
# 0       [64] - 4 - [512, 256] - ['global_mean_pool']
# 0  [64] - 3 - [512] - ['global_mean_pool', 'globa...
# 0               [64] - 3 - [] - ['global_mean_pool']
# 0           [512] - 2 - [512] - ['global_mean_pool']
# 0              [512] - 2 - [] - ['global_mean_pool']
# 0               [512] - 2 - [] - ['global_max_pool']
# 0  [256] - 1 - [512, 256] - ['global_mean_pool', ...
# 0            [512] - 2 - [512] - ['global_max_pool']
# 0       [512] - 2 - [512, 256] - ['global_max_pool']
# 0               [256] - 2 - [] - ['global_max_pool']
# 0            [256] - 2 - [512] - ['global_max_pool']
# 0      [256] - 2 - [512, 256] - ['global_mean_pool']
# 0  [256] - 1 - [512] - ['global_mean_pool', 'glob...
# 0              [256] - 2 - [] - ['global_mean_pool']
# 0  [512] - 1 - [512, 256] - ['global_mean_pool', ...
# 0  [64] - 1 - [512] - ['global_mean_pool', 'globa...
# 0  [512] - 1 - [512] - ['global_mean_pool', 'glob...
# 0       [64] - 3 - [512, 256] - ['global_mean_pool']
# 0  [64] - 2 - [512] - ['global_mean_pool', 'globa...
# 0           [256] - 2 - [512] - ['global_mean_pool']
# 0  [64] - 3 - [512, 256] - ['global_mean_pool', '...
# 0                [64] - 3 - [] - ['global_max_pool']
# 0               [64] - 2 - [] - ['global_mean_pool']
# 0       [256] - 2 - [512, 256] - ['global_max_pool']
# 0  [64] - 1 - [512, 256] - ['global_mean_pool', '...
# 0  [64] - 1 - [] - ['global_mean_pool', 'global_m...
# 0       [64] - 2 - [512, 256] - ['global_mean_pool']
# 0        [64] - 2 - [512, 256] - ['global_max_pool']
# 0            [64] - 2 - [512] - ['global_mean_pool']
# 0                [64] - 2 - [] - ['global_max_pool']
# 0      [512] - 1 - [512, 256] - ['global_mean_pool']
# 0  [256] - 1 - [] - ['global_mean_pool', 'global_...
# 0              [512] - 1 - [] - ['global_mean_pool']
# 0             [64] - 2 - [512] - ['global_max_pool']
# 0           [512] - 1 - [512] - ['global_mean_pool']
# 0           [256] - 1 - [512] - ['global_mean_pool']
# 0      [256] - 1 - [512, 256] - ['global_mean_pool']
# 0              [256] - 1 - [] - ['global_mean_pool']
# 0            [256] - 1 - [512] - ['global_max_pool']
# 0               [512] - 1 - [] - ['global_max_pool']
# 0            [512] - 1 - [512] - ['global_max_pool']
# 0       [256] - 1 - [512, 256] - ['global_max_pool']
# 0       [512] - 1 - [512, 256] - ['global_max_pool']
# 0               [256] - 1 - [] - ['global_max_pool']
# 0               [64] - 1 - [] - ['global_mean_pool']
# 0                [64] - 1 - [] - ['global_max_pool']
# 0             [64] - 1 - [512] - ['global_max_pool']
# 0            [64] - 1 - [512] - ['global_mean_pool']
# 0        [64] - 1 - [512, 256] - ['global_max_pool']
# 0       [64] - 1 - [512, 256] - ['global_mean_pool']

# %%
fullplot1.sort_values(by=['lossvalue_l1'])
# Out:
#   hidden_channels  gcn_layers linear_sizes  \
# 0           [512]           2        [512]
# 0           [512]           3   [512, 256]
# 0           [512]           2           []
# 0           [512]           3           []
# 0           [256]           3   [512, 256]
# 0           [512]           3        [512]
# 0           [256]           4   [512, 256]
# 0           [256]           3        [512]
# 0           [256]           3           []
# 0           [256]           2   [512, 256]
# 0           [512]           4           []
# 0           [256]           2        [512]
# 0           [512]           3        [512]
# 0           [256]           3        [512]
# 0           [512]           4           []
# 0           [512]           3           []
# 0           [256]           4           []
# 0           [256]           3           []
# 0            [64]           3   [512, 256]
# 0           [256]           4   [512, 256]
# 0           [512]           2   [512, 256]
# 0           [512]           4        [512]
# 0           [256]           4        [512]
# 0           [512]           3   [512, 256]
# 0            [64]           3        [512]
# 0            [64]           3           []
# 0           [512]           3   [512, 256]
# 0           [256]           2           []
# 0           [512]           4   [512, 256]
# 0            [64]           4   [512, 256]
# 0           [256]           4   [512, 256]
# 0           [256]           3   [512, 256]
# 0            [64]           4           []
# 0           [512]           2           []
# 0           [512]           4   [512, 256]
# 0           [256]           4        [512]
# 0           [256]           3   [512, 256]
# 0           [256]           4           []
# 0            [64]           4   [512, 256]
# 0           [512]           4        [512]
# 0            [64]           4           []
# 0           [512]           2        [512]
# 0           [512]           4   [512, 256]
# 0           [512]           4        [512]
# 0            [64]           2           []
# 0            [64]           4        [512]
# 0            [64]           2   [512, 256]
# 0           [512]           4           []
# 0           [512]           1           []
# 0           [256]           4           []
# 0           [256]           2           []
# 0           [256]           3        [512]
# 0            [64]           4        [512]
# 0           [512]           3        [512]
# 0           [256]           4        [512]
# 0           [256]           2        [512]
# 0           [512]           2   [512, 256]
# 0            [64]           4           []
# 0            [64]           4        [512]
# 0           [512]           3           []
# 0            [64]           3        [512]
# 0           [512]           2   [512, 256]
# 0           [256]           1   [512, 256]
# 0           [256]           3           []
# 0            [64]           4   [512, 256]
# 0           [256]           2   [512, 256]
# 0           [512]           1   [512, 256]
# 0            [64]           3        [512]
# 0            [64]           3           []
# 0           [512]           1        [512]
# 0           [256]           1        [512]
# 0            [64]           1        [512]
# 0            [64]           2        [512]
# 0           [256]           2   [512, 256]
# 0           [512]           2        [512]
# 0            [64]           3   [512, 256]
# 0           [512]           2           []
# 0            [64]           1           []
# 0           [256]           2           []
# 0            [64]           3           []
# 0            [64]           3   [512, 256]
# 0            [64]           2           []
# 0            [64]           1   [512, 256]
# 0            [64]           2   [512, 256]
# 0           [256]           2        [512]
# 0            [64]           2           []
# 0            [64]           2   [512, 256]
# 0            [64]           2        [512]
# 0           [512]           1   [512, 256]
# 0           [256]           1           []
# 0           [512]           1           []
# 0           [256]           1        [512]
# 0           [512]           1        [512]
# 0            [64]           2        [512]
# 0           [512]           1        [512]
# 0           [512]           1           []
# 0           [256]           1        [512]
# 0           [256]           1           []
# 0           [512]           1   [512, 256]
# 0           [256]           1   [512, 256]
# 0           [256]           1   [512, 256]
# 0           [256]           1           []
# 0            [64]           1           []
# 0            [64]           1        [512]
# 0            [64]           1           []
# 0            [64]           1        [512]
# 0            [64]           1   [512, 256]
# 0            [64]           1   [512, 256]
#
#                           aggregations  lossvalue_mse  lossvalue_l1  \
# 0  [global_mean_pool, global_max_pool]       0.454284      0.505999
# 0  [global_mean_pool, global_max_pool]       0.507662      0.511903
# 0  [global_mean_pool, global_max_pool]       0.470886      0.514185
# 0  [global_mean_pool, global_max_pool]       0.540469      0.520313
# 0  [global_mean_pool, global_max_pool]       0.543321      0.533611
# 0  [global_mean_pool, global_max_pool]       0.548231      0.546768
# 0  [global_mean_pool, global_max_pool]       0.547392      0.551128
# 0  [global_mean_pool, global_max_pool]       0.568955      0.554658
# 0                    [global_max_pool]       0.685159      0.565472
# 0  [global_mean_pool, global_max_pool]       0.586896      0.566953
# 0                   [global_mean_pool]       0.576426      0.568877
# 0  [global_mean_pool, global_max_pool]       0.655926      0.571070
# 0                    [global_max_pool]       0.658307      0.571159
# 0                    [global_max_pool]       0.682665      0.575683
# 0  [global_mean_pool, global_max_pool]       0.599237      0.575865
# 0                    [global_max_pool]       0.692947      0.580446
# 0  [global_mean_pool, global_max_pool]       0.622197      0.583451
# 0  [global_mean_pool, global_max_pool]       0.662569      0.586409
# 0                    [global_max_pool]       0.666648      0.587391
# 0                   [global_mean_pool]       0.632519      0.588585
# 0  [global_mean_pool, global_max_pool]       0.670936      0.590996
# 0  [global_mean_pool, global_max_pool]       0.666787      0.592800
# 0                    [global_max_pool]       0.707998      0.594951
# 0                   [global_mean_pool]       0.635613      0.595348
# 0                    [global_max_pool]       0.715998      0.597116
# 0  [global_mean_pool, global_max_pool]       0.670306      0.598521
# 0                    [global_max_pool]       0.730111      0.601707
# 0  [global_mean_pool, global_max_pool]       0.632834      0.601812
# 0                   [global_mean_pool]       0.625519      0.603751
# 0                    [global_max_pool]       0.703264      0.612638
# 0                    [global_max_pool]       0.726065      0.615329
# 0                    [global_max_pool]       0.737036      0.618150
# 0  [global_mean_pool, global_max_pool]       0.720099      0.618588
# 0                    [global_max_pool]       0.909152      0.619027
# 0  [global_mean_pool, global_max_pool]       0.702078      0.619766
# 0  [global_mean_pool, global_max_pool]       0.695505      0.622417
# 0                   [global_mean_pool]       0.670078      0.625256
# 0                    [global_max_pool]       0.668376      0.626459
# 0  [global_mean_pool, global_max_pool]       0.671711      0.627676
# 0                   [global_mean_pool]       0.715349      0.628009
# 0                    [global_max_pool]       0.746323      0.633061
# 0                    [global_max_pool]       0.918590      0.637531
# 0                    [global_max_pool]       0.782813      0.639094
# 0                    [global_max_pool]       0.836654      0.639577
# 0  [global_mean_pool, global_max_pool]       0.733485      0.640640
# 0                    [global_max_pool]       0.807926      0.641106
# 0  [global_mean_pool, global_max_pool]       0.766579      0.642472
# 0                    [global_max_pool]       0.796039      0.643134
# 0  [global_mean_pool, global_max_pool]       0.838546      0.644290
# 0                   [global_mean_pool]       0.724483      0.647323
# 0                    [global_max_pool]       0.964302      0.652210
# 0                   [global_mean_pool]       0.691752      0.652792
# 0  [global_mean_pool, global_max_pool]       0.725737      0.653910
# 0                   [global_mean_pool]       0.740921      0.656450
# 0                   [global_mean_pool]       0.739295      0.658176
# 0                    [global_max_pool]       0.983705      0.658819
# 0                    [global_max_pool]       0.927070      0.659493
# 0                   [global_mean_pool]       0.749703      0.661114
# 0                   [global_mean_pool]       0.812334      0.679570
# 0                   [global_mean_pool]       0.738299      0.679986
# 0  [global_mean_pool, global_max_pool]       0.845349      0.681427
# 0                   [global_mean_pool]       0.764355      0.695703
# 0  [global_mean_pool, global_max_pool]       0.917204      0.697242
# 0                   [global_mean_pool]       0.816954      0.701930
# 0                   [global_mean_pool]       0.842818      0.703656
# 0                    [global_max_pool]       1.129797      0.705835
# 0  [global_mean_pool, global_max_pool]       1.002977      0.710521
# 0                   [global_mean_pool]       0.817177      0.713913
# 0                   [global_mean_pool]       0.860759      0.714411
# 0  [global_mean_pool, global_max_pool]       1.020053      0.719313
# 0  [global_mean_pool, global_max_pool]       0.987057      0.719486
# 0  [global_mean_pool, global_max_pool]       1.004835      0.724967
# 0  [global_mean_pool, global_max_pool]       1.032611      0.739675
# 0                   [global_mean_pool]       0.984079      0.743549
# 0                   [global_mean_pool]       0.892529      0.748549
# 0  [global_mean_pool, global_max_pool]       1.071418      0.759657
# 0                   [global_mean_pool]       0.900645      0.760998
# 0  [global_mean_pool, global_max_pool]       1.159147      0.762873
# 0                   [global_mean_pool]       0.998963      0.766358
# 0                    [global_max_pool]       1.077926      0.769036
# 0                   [global_mean_pool]       1.031367      0.786024
# 0                    [global_max_pool]       1.242419      0.788718
# 0  [global_mean_pool, global_max_pool]       1.139992      0.790107
# 0                    [global_max_pool]       1.214060      0.793913
# 0                   [global_mean_pool]       1.045301      0.795555
# 0                   [global_mean_pool]       1.122710      0.807854
# 0                   [global_mean_pool]       1.204106      0.836429
# 0                   [global_mean_pool]       1.216218      0.836742
# 0                   [global_mean_pool]       1.264194      0.845025
# 0  [global_mean_pool, global_max_pool]       1.333792      0.854193
# 0                   [global_mean_pool]       1.339470      0.872475
# 0                   [global_mean_pool]       1.349275      0.873578
# 0                   [global_mean_pool]       1.347403      0.874941
# 0                    [global_max_pool]       1.343743      0.897272
# 0                    [global_max_pool]       1.751824      0.900908
# 0                    [global_max_pool]       1.695134      0.924430
# 0                    [global_max_pool]       1.644605      0.928234
# 0                   [global_mean_pool]       1.475654      0.928847
# 0                    [global_max_pool]       1.776518      0.929123
# 0                   [global_mean_pool]       1.457952      0.929450
# 0                    [global_max_pool]       1.761517      0.949008
# 0                    [global_max_pool]       1.794586      0.965650
# 0                    [global_max_pool]       1.892769      0.980830
# 0                    [global_max_pool]       1.955811      0.983729
# 0                   [global_mean_pool]       1.879950      1.085678
# 0                   [global_mean_pool]       1.998819      1.111967
# 0                    [global_max_pool]       2.144246      1.135082
# 0                   [global_mean_pool]       2.320485      1.229188
#
#                                       Combined Label
# 0  [512] - 2 - [512] - ['global_mean_pool', 'glob...
# 0  [512] - 3 - [512, 256] - ['global_mean_pool', ...
# 0  [512] - 2 - [] - ['global_mean_pool', 'global_...
# 0  [512] - 3 - [] - ['global_mean_pool', 'global_...
# 0  [256] - 3 - [512, 256] - ['global_mean_pool', ...
# 0  [512] - 3 - [512] - ['global_mean_pool', 'glob...
# 0  [256] - 4 - [512, 256] - ['global_mean_pool', ...
# 0  [256] - 3 - [512] - ['global_mean_pool', 'glob...
# 0               [256] - 3 - [] - ['global_max_pool']
# 0  [256] - 2 - [512, 256] - ['global_mean_pool', ...
# 0              [512] - 4 - [] - ['global_mean_pool']
# 0  [256] - 2 - [512] - ['global_mean_pool', 'glob...
# 0            [512] - 3 - [512] - ['global_max_pool']
# 0            [256] - 3 - [512] - ['global_max_pool']
# 0  [512] - 4 - [] - ['global_mean_pool', 'global_...
# 0               [512] - 3 - [] - ['global_max_pool']
# 0  [256] - 4 - [] - ['global_mean_pool', 'global_...
# 0  [256] - 3 - [] - ['global_mean_pool', 'global_...
# 0        [64] - 3 - [512, 256] - ['global_max_pool']
# 0      [256] - 4 - [512, 256] - ['global_mean_pool']
# 0  [512] - 2 - [512, 256] - ['global_mean_pool', ...
# 0  [512] - 4 - [512] - ['global_mean_pool', 'glob...
# 0            [256] - 4 - [512] - ['global_max_pool']
# 0      [512] - 3 - [512, 256] - ['global_mean_pool']
# 0             [64] - 3 - [512] - ['global_max_pool']
# 0  [64] - 3 - [] - ['global_mean_pool', 'global_m...
# 0       [512] - 3 - [512, 256] - ['global_max_pool']
# 0  [256] - 2 - [] - ['global_mean_pool', 'global_...
# 0      [512] - 4 - [512, 256] - ['global_mean_pool']
# 0        [64] - 4 - [512, 256] - ['global_max_pool']
# 0       [256] - 4 - [512, 256] - ['global_max_pool']
# 0       [256] - 3 - [512, 256] - ['global_max_pool']
# 0  [64] - 4 - [] - ['global_mean_pool', 'global_m...
# 0               [512] - 2 - [] - ['global_max_pool']
# 0  [512] - 4 - [512, 256] - ['global_mean_pool', ...
# 0  [256] - 4 - [512] - ['global_mean_pool', 'glob...
# 0      [256] - 3 - [512, 256] - ['global_mean_pool']
# 0               [256] - 4 - [] - ['global_max_pool']
# 0  [64] - 4 - [512, 256] - ['global_mean_pool', '...
# 0           [512] - 4 - [512] - ['global_mean_pool']
# 0                [64] - 4 - [] - ['global_max_pool']
# 0            [512] - 2 - [512] - ['global_max_pool']
# 0       [512] - 4 - [512, 256] - ['global_max_pool']
# 0            [512] - 4 - [512] - ['global_max_pool']
# 0  [64] - 2 - [] - ['global_mean_pool', 'global_m...
# 0             [64] - 4 - [512] - ['global_max_pool']
# 0  [64] - 2 - [512, 256] - ['global_mean_pool', '...
# 0               [512] - 4 - [] - ['global_max_pool']
# 0  [512] - 1 - [] - ['global_mean_pool', 'global_...
# 0              [256] - 4 - [] - ['global_mean_pool']
# 0               [256] - 2 - [] - ['global_max_pool']
# 0           [256] - 3 - [512] - ['global_mean_pool']
# 0  [64] - 4 - [512] - ['global_mean_pool', 'globa...
# 0           [512] - 3 - [512] - ['global_mean_pool']
# 0           [256] - 4 - [512] - ['global_mean_pool']
# 0            [256] - 2 - [512] - ['global_max_pool']
# 0       [512] - 2 - [512, 256] - ['global_max_pool']
# 0               [64] - 4 - [] - ['global_mean_pool']
# 0            [64] - 4 - [512] - ['global_mean_pool']
# 0              [512] - 3 - [] - ['global_mean_pool']
# 0  [64] - 3 - [512] - ['global_mean_pool', 'globa...
# 0      [512] - 2 - [512, 256] - ['global_mean_pool']
# 0  [256] - 1 - [512, 256] - ['global_mean_pool', ...
# 0              [256] - 3 - [] - ['global_mean_pool']
# 0       [64] - 4 - [512, 256] - ['global_mean_pool']
# 0       [256] - 2 - [512, 256] - ['global_max_pool']
# 0  [512] - 1 - [512, 256] - ['global_mean_pool', ...
# 0            [64] - 3 - [512] - ['global_mean_pool']
# 0               [64] - 3 - [] - ['global_mean_pool']
# 0  [512] - 1 - [512] - ['global_mean_pool', 'glob...
# 0  [256] - 1 - [512] - ['global_mean_pool', 'glob...
# 0  [64] - 1 - [512] - ['global_mean_pool', 'globa...
# 0  [64] - 2 - [512] - ['global_mean_pool', 'globa...
# 0      [256] - 2 - [512, 256] - ['global_mean_pool']
# 0           [512] - 2 - [512] - ['global_mean_pool']
# 0  [64] - 3 - [512, 256] - ['global_mean_pool', '...
# 0              [512] - 2 - [] - ['global_mean_pool']
# 0  [64] - 1 - [] - ['global_mean_pool', 'global_m...
# 0              [256] - 2 - [] - ['global_mean_pool']
# 0                [64] - 3 - [] - ['global_max_pool']
# 0       [64] - 3 - [512, 256] - ['global_mean_pool']
# 0                [64] - 2 - [] - ['global_max_pool']
# 0  [64] - 1 - [512, 256] - ['global_mean_pool', '...
# 0        [64] - 2 - [512, 256] - ['global_max_pool']
# 0           [256] - 2 - [512] - ['global_mean_pool']
# 0               [64] - 2 - [] - ['global_mean_pool']
# 0       [64] - 2 - [512, 256] - ['global_mean_pool']
# 0            [64] - 2 - [512] - ['global_mean_pool']
# 0      [512] - 1 - [512, 256] - ['global_mean_pool']
# 0  [256] - 1 - [] - ['global_mean_pool', 'global_...
# 0              [512] - 1 - [] - ['global_mean_pool']
# 0           [256] - 1 - [512] - ['global_mean_pool']
# 0           [512] - 1 - [512] - ['global_mean_pool']
# 0             [64] - 2 - [512] - ['global_max_pool']
# 0            [512] - 1 - [512] - ['global_max_pool']
# 0               [512] - 1 - [] - ['global_max_pool']
# 0            [256] - 1 - [512] - ['global_max_pool']
# 0              [256] - 1 - [] - ['global_mean_pool']
# 0       [512] - 1 - [512, 256] - ['global_max_pool']
# 0      [256] - 1 - [512, 256] - ['global_mean_pool']
# 0       [256] - 1 - [512, 256] - ['global_max_pool']
# 0               [256] - 1 - [] - ['global_max_pool']
# 0                [64] - 1 - [] - ['global_max_pool']
# 0             [64] - 1 - [512] - ['global_max_pool']
# 0               [64] - 1 - [] - ['global_mean_pool']
# 0            [64] - 1 - [512] - ['global_mean_pool']
# 0        [64] - 1 - [512, 256] - ['global_max_pool']
# 0       [64] - 1 - [512, 256] - ['global_mean_pool']

# %%
fullplot1.set_index('Combined Label', inplace=True)

fullplot1['lossvalue_mse'].plot(kind='bar')
# Out:
# <Axes: xlabel='Combined Label'>
